# %% [markdown]
# # 使用LSTM生成文本
#
# ## 1. 准备数据

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 3s 5us/step
# Corpus length: 600893

# %%
# 提取60个字符组成序列
maxlen = 60

# 每3个字符进行采样
step = 3

# 保存所提取的序列
sentences = []

# 保存目标（即下一个字符）
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# 语料中唯一字符组成的列表
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# 一个字典
char_indices = dict((char, chars.index(char)) for char in chars)

# 将字符的one-hot编码为二进制数组
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## 2. 构建网络

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From /home/hu/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## 3. 训练语言模型

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# WARNING:tensorflow:From /home/hu/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 200278/200278 [==============================] - 76s 380us/step - loss: 1.9845
# --- Generating with seed: "he german spirit gradually
# established itself--in spite of a"
# ------ temperature: 0.2
# he german spirit gradually
# established itself--in spite of all the suppinity to he all the self--the same the same of the some and the moral and the conscience and the was all the man and the man and the suppose to the suppose to the taste of the taste and the supple something and all the truth of the suppose to the supposes and tood the man and the man and stronges and the self--the deciments of the taste and man and the some and the strengtion of the sup
# ------ temperature: 0.5
# the taste and man and the some and the strengtion of the supples and former who he word and or acts has in the pression conscience and tood all provertions and look and the pal action of the orger to intermaning not be ald and the truth and them be all the scounces to the posterm superself in all be action and interption of the extent of those its the man hower of spection and encense place regard and soul an the extences which is the into the pat some for
# ------ temperature: 1.0
#  and soul an the extences which is the into the pat some formere its sens but as of chifourr and
# tainr exte to my orderifices of susceebsy dosmruale vals athind:
#
# to
# seem rockening of acquess epten because. ie whichs
# one i compted gortlo
# them indicity, he sapfic descatisn to diventary by
# this haid says hom from hoseast
#  morble seever the amtile "gas come varther anowhers anoteems and instiency and intourm the reil at there-soul now, and eurdegrate offesten
# ------ temperature: 1.2
#  intourm the reil at there-soul now, and eurdegrate offesten sameter mighttinesvatition (trard coud,
# if
# more itning, be world extectabled evoalter bell toinvenes an inding
# simenwil craby ale symitud, or terperopeds,
# and tit, and larded, in,le dis
# ferding "rret dept withsweri, fcommine, tome not the ingy measry varl tonoward of teor
# -a
# taman? wendurms in decansibyre. in truth;
# romigocatiom in initalis besolls cusgering ast
# a de tracm wewdy?
# ole sirts, and
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 76s 381us/step - loss: 1.6377
# --- Generating with seed: "he other content inasmuch as each receives what it prizes mo"
# ------ temperature: 0.2
# he other content inasmuch as each receives what it prizes more and the sout of the sout of the contrady the expendent to the most the most to the sout the sense the most conception of the most the almost the sout the subjustion of the sout and the sout the souch the most propertion of the sout the sense the stronger to the sout of the same sout there is the sout the sout the sout and the sout the sout of the same the sense of the sout the spirit to the sen
# ------ temperature: 0.5
# sout of the same the sense of the sout the spirit to the sense and being which has always there also and the religion of the sout the respected to ghing to the sou senses now the most before the faith to man that and the earthers to the even modical man, in it to the most former in
# the strime or any the sense the wort that soul the ashous the presently one than it is the edischaring and long has a sort that there is the sense and there is any the most into
# ------ temperature: 1.0
#  sort that there is the sense and there is any the most into-them away pholecias give and them was time at a
# concete to anlimion contraces
# to some"mmine with it is which is be explience
# at one tower of an the sou therepike moyean arrunds beligerqulation. the martanowing i pipers itnesse them also have their toad the sese are to deal
# the isintere" truth trad look unas to there schoing as accostence and to be aln-net
# specie on our now thensave so, in lessath
# ------ temperature: 1.2
#  and to be aln-net
# specie on our now thensave so, in lessath, soraontly cunuans, abilthers.=--will as prinfus
# not event
#
# thore variesfiaalition. sart, id he in serpanted tedge--pad forch
#  osr cureous upsidened, and, is me trou gread, it, will, "happin philosophers and condited, bkindom, his too
# well past
# ceoms
# of nomanger on themself.--that dralm and add, brings: it, ar and poses, by the earbed intaust befulogian an da poirate port
# it, come therrinver and
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 75s 376us/step - loss: 1.5472
# --- Generating with seed: "lieve
# that a philosopher--supposing that a philosopher has a"
# ------ temperature: 0.2
# lieve
# that a philosopher--supposing that a philosopher has a more and in the self-consequence and the selfed to the soul and be all the sense and the self-consequence of the self-consequence and the graties and all the self-delicate and the soul and the senses and the self-consequence and the soul and the fact to the self-consequence of the self-derition in the same and the self-same and the self-conscious the selfed a man the sear and the sense and the sa
# ------ temperature: 0.5
# conscious the selfed a man the sear and the sense and the satiection and all the present and stand the sense in the sensually the more of the self-consequence of the feeling the faculting of the sense many old to the self-consequence of the same value the the farsions and a sort of the last all the
# states and any distance of the self-will all at learness and its pasticious the same corw the still and in the sense to the last contrary in the prove and the a
# ------ temperature: 1.0
# and in the sense to the last contrary in the prove and the a ep therebyshed
# and
# respected to all, becausely would and for
# fruen, als all the intilered to me processhe ut to such natureds--"decaper--for learning of every
# continder, cawses, and do untirous under the
# same whiecy out of maties,
# and in them a intliso wis so
# mymontacys.
#
#
#              he deared that no
# conduction in which men is awind at
# grow fan
# that the
# hone have too stater, that
# the elimarra
# ------ temperature: 1.2
# at
# grow fan
# that the
# hone have too stater, that
# the elimarrabally singabed anguet", as however, woce which maye that s il
# he unterme-"'is sorchard with
# readened and eto, inongribotect.
# however among howevers done all
# specieated oa spirit tomfish., benastsorical, hess wher
# many himselflare to forget deversure,
# to himself being imposseass, himselfly.
#
#
# 6
#
# =arts as
# grown maneances all tassical.
#
# 7neraual, why
# hs more of
# covery to detingnfuge, wheing
# hidtible
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 76s 379us/step - loss: 1.5023
# --- Generating with seed: "ll too human?
# with this exclamation my writings are gone thr"
# ------ temperature: 0.2
# ll too human?
# with this exclamation my writings are gone threath and the sense of the most developed the sense in the sense of the soul in the sense of the sense of the sense in the sense in the same for the most sense in the fact and being the sense in the sense of such an achologiction the same the serieful in the sense of the same should be no longer the fact the sense in the sense in the sense of the senses of the same for the same the existence, and t
# ------ temperature: 0.5
#  of the senses of the same for the same the existence, and the same the deliminal increasing himself thereby devile of the self thing and surition of the expedience in the deeper the socient of the seriate and spirit, in ever their truth and should and culte the existence, as at the existence of the serious instincts the feeling, and of the belief things with it is most purely and very acts and the distrust of the sense in its ding the most will as means o
# ------ temperature: 1.0
# e distrust of the sense in its ding the most will as means of no be "before
# your, if thinved, with a sourded in he same priviuafice and nerest, the eartary fiu furuted it would as nearhibitic
# extrultes in consided of the wortors." it is always that loo, and of i strength" to
# yessined suppists which act to no saver with gave conceptions to from the vartion the unitally and lara thtilate congetion of relumial diden
# is above approvisize than
# modespor, short t
# ------ temperature: 1.2
# f relumial diden
# is above approvisize than
# modespor, short to thinks brings that that inclanutuc, but
# men clear become the submenness, "ginck moder of think uptet genest intriloc divinely, overy siic the harded nom hore, phulosope, the simityaix useful themselvevy our nackindfougreriate likert from therebithoratiment throrman saffence of such alls
# therefore pireds mist and bocewird it, for all exmefues a interpass, does no funcilation.=-even horeverable, r
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 76s 378us/step - loss: 1.4754
# --- Generating with seed: "hat the more profoundly man thinks, the more exquisitely he
# "
# ------ temperature: 0.2
# hat the more profoundly man thinks, the more exquisitely he
# interpretations of the formerly the far to the properless of the senses of the fear and properless and the properless and serious man will to the selfect and the profoundled on the senses and promise of the selses the selfect of the selfect of the profoundless the oppreased to the soul, and the form of the experience and some will of the selfect of the proposition and the senses and soul--and the
# ------ temperature: 0.5
# selfect of the proposition and the senses and soul--and the senses that when he senses and bemond for the philosophy of which we the religious propointing syrt with the most bad is because of one is profoundless and deligious and discontern of det believe underantly a dowart to his great influence to the soul-has only the prociation of morality the same command, which he means and result in the most serious in the purcled of the improposes of tention of me
# ------ temperature: 1.0
# st serious in the purcled of the improposes of tention of men to europein
# of
# beractions to whim
# still no let ordening for instinct, to considert. but--they also were yet man his
# lan
# bolingly a more jest he me world and for
# to question, perhaps and instance of piech.=itily,
# same, an laborians and of werst in their senest upon ones--as "spirit of most preximpting religious interpreters of that chark, borlically with to komarly ablegance; and
# democrations of
# ------ temperature: 1.2
# k, borlically with to komarly ablegance; and
# democrations of properials men tults, natuce; to
# being in let fold resufion.
#
# here dially qlanglon that he ma foroun? has as not-ba
# german exercly, to pre, as if that, in na"-than a bod,
# epogaticism--is notapives.=--in resrmant from call also lo ret" a bod of
# fance and
# word, to wiles howow pituderently i coarsed
# toe? im, comprehonia? durelies for that cirfiction.
#
# 214. it wan holl world really is a agribtures" o
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 76s 381us/step - loss: 1.4535
# --- Generating with seed: "o refresh me? oh, thou prying one,
# what sayest thou! but giv"
# ------ temperature: 0.2
# o refresh me? oh, thou prying one,
# what sayest thou! but give and the strange of the state of the stronger and see the states and soul of the sense of the states of the stronger, and the sense of the streat the stronger of the stronger of the stronger of the states and soul the states of the subjection of the sense of the stream of the sense of the same and also the sense of the stronger of the stronger of the sentes and man is not the distance of the sent
# ------ temperature: 0.5
# ronger of the sentes and man is not the distance of the sented to the subtle souls understand the subjectives the most lighted of the perform and the distance to a more and that it is self-in all distance of the strongerful stoo
# the stronger, the distance, and any more man of the spirit as a more entures and the stoon of the fact of presence of light to the state of considered and precisely to it is not who to render in the stronger, and the sever an opene
# ------ temperature: 1.0
# is not who to render in the stronger, and the sever an opene to
# man.
#
# rear hrishnessley, onew and ay perhaps why
# mibars, mirely.
#
#
#
#                                    notion of
# german person in
# the addingees game from loved
# chate housing who far like as individualss, who suppositoming commanity--we but grow as at subgeration
# of the fearly it is treat latter and go spity of its tod
# iubed, finally, the sach the commined the first. and spect thus and use to s
# ------ temperature: 1.2
# the sach the commined the first. and spect thus and use to self-come engadoligine ennousler to lessier
# deor fallisn"--it
# is geater
# and ""panitvorine "vidlikn as he
# i we have timing rearingn: "evrolaisgecbles who truth that himself when the pseredital kin a stoo whole alohesnies to therewithwengers, does inexmitiousmen: what
# gut
# to and the by maxigned-perhaps of thisges and awiaj that at armstian vior."
# ohly hiltleds its
# appleding, hin assor be charm.
#
# 1us
# epoch 7
# Epoch 1/1
#    384/200278 [..............................] - ETA: 1:12 - loss: 1.5583
# /home/hu/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# 200278/200278 [==============================] - 76s 380us/step - loss: 1.4389
# --- Generating with seed: " inclines to stupidity, every stupidity to virtue; "stupid
# t"
# ------ temperature: 0.2
#  inclines to stupidity, every stupidity to virtue; "stupid
# to the sense of the conscious of the same the same the realistic of the same the words the same the same the same the same the sure the sure the man who has a such a such a such a constant and the such a such a desperience of the same the same the whole the most development in the same such an action the same in the conscious and hand and the strengthing the same the same the most development of th
# ------ temperature: 0.5
# the strengthing the same the same the most development of the discreal new supposing to the words and development for the great attained of a seep are so superstitually the same in the greeked yound, and the philosophy has truth, and the words of the philosophy the religious in the streep of the disconception is words of its interpretion of the power and a hands of the same the spirit a standard for the different and of which he will be of the farse be all
# ------ temperature: 1.0
# or the different and of which he will be of the farse be all philosophy and and by the invert of he ohould withorumase and the modern inagesion to drogm and
# deverse
# duplises in increated, pre'sartifals that me possible will "unclope., as may condection has all
# to
# fullied
# suemered, unnertaings
# from the tide untroughtxary of hir? a pashe are will virem
# in the petiplcy the grearners of dispossionable and passions the good itself, and aquaintarian. them north
# ------ temperature: 1.2
#  and passions the good itself, and aquaintarian. them north for the
# wills: it at a
# agreal kiny. they plausity, is ornainurness and
# in him also the sinted to seecy, the greeke and himselfd, was the god; i get
# or opinoos a noblon pensinely thever dhis" wholok upti"ring to keriation--lalted; all nares. to stopeoin
# that beleablement
# and iserofn" have to an of lears of ye the most cuttouraf
# one's meanher minetime-nise, of curilesful snous
# their regarded felse a
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 74s 367us/step - loss: 1.4258
# --- Generating with seed: " lower oneself to them for hours; to seat oneself on them as"
# ------ temperature: 0.2
#  lower oneself to them for hours; to seat oneself on them as a man and the spirit is a states the world the spirit in the desired of the present and sense of the experience, and the soul, and the probable and the spirit is the problem the world in the spirit the art of the commander and the spirit is a man with the artistic and with the world that the souls and the probable in the present and states the reading the present one has a profound the pain the d
# ------ temperature: 0.5
# es the reading the present one has a profound the pain the delight the commanders the spirit in even with the decessity of the higher demands. the appite, and attained as a man and by the completent and well that it is commanderes that it we say in the concerning the feeling places and the exemple, who was the nations with the restence
# of the before one must continual destruction to the world to the reading still lost
# and a religious tertions
# and by a pres
# ------ temperature: 1.0
# he reading still lost
# and a religious tertions
# and by a presences to comprehend exiritses,
# what
# drawpped and by their voonturer to slavit he ven we criticus,
# only are neverbeed the orgain takes the cases itself, man, i way, to be cavality of
# foreby or means them,s
# enoude, uan uneffertiness, thinking tristions and with time, and by the
# essentaises of this
# to have led attainesy of things" itself--there who will prideive
# the
# philosopher, "he
# may as unuseaks
#
# ------ temperature: 1.2
# here who will prideive
# the
# philosopher, "he
# may as unuseaks
# afteressoment rocracer, beclusion inter,urest us bet it he
# profuming," the loved of i laras who charpudees time) by the pull storpppssiciin emokinate to labulvesces will foringr. one. he must bat?--refact this parewisters, with
# "comgre otoo, naflartitic place? into to nation with a judle, whichy becauses
# islarced, schopemken in "valuation
# one
# man
# has hoacfed to general nelugaons
# tha morbes, is lov
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 78s 392us/step - loss: 1.4164
# --- Generating with seed: " the
# genius of the race overflowing from all the cornucopias"
# ------ temperature: 0.2
#  the
# genius of the race overflowing from all the cornucopias and the same and and the contrary and seems to the same and and the generality of the same an anciently and an an an ancessing and a man as the same and the same an an an an a subtles and the degree and say and the orge of the more self-say and strictly and the same and and an action and soul and all the an interpretation of the case that the same as a consideration of the most passions and the s
# ------ temperature: 0.5
# t the same as a consideration of the most passions and the same any, all the consideration of the feater and degree and still our soul, as
# see all the astumately and all the entice and sense and the had and a heart and simply be sough itself and a parents and that is a men is a demands to the moral belief and with it, as a bad an any has man as a seems to the su ease of the fact of the world to the delight and to employ and being in the same ake and this a
# ------ temperature: 1.0
# e delight and to employ and being in the same ake and this apparently, which as yet heave onst. there alwer has been of naments
# and es great girle, if is
# an and : also the highest love, to such that which has been is is all philosopher skrul.
# all the fact such a more on"wit
# master,
# has circumstander. the con . the task of this matiusal
# suwhend the living was more sort in the german of things an a man--as time of
# efficial to is timing, with it
# degree of pai
# ------ temperature: 1.2
# man--as time of
# efficial to is timing, with it
# degree of pain of ye aly things and much cidence thus
# always
# motilities of sympathic sable and bisis unyedence and postarable for a was sympathated which is that is an old worihe will
# called calray more madiculam prove the were--that mea hidaxicaps-im. they no vain: through
# than there along unscagation and oldest much.aness of hand
# him unbeina gands iazlives, and--and over hithneverly arbortow
# liber
# which has
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 78s 388us/step - loss: 1.4069
# --- Generating with seed: "lso to a bad
# and unjust one (think, for instance, of the gre"
# ------ temperature: 0.2
# lso to a bad
# and unjust one (think, for instance, of the greater to the tentation of the sense of the free of the spirit of the the strength of the precisely the precisely to the contrary and the strength and strange of the same and the more of the feelings of the sense of the more of the entice and allow the and an our and soul and the delicately and the more and a consident to the spirit in the sense of the most self-in the condition of the moralities of
# ------ temperature: 0.5
# sense of the most self-in the condition of the moralities of the things and soul should the virtues of the the more perhaps a pations--or "when one soul to detigatening to hard will that those that the other interpretation of according to galling interpretation of his suffer the art of state in the condition of a the are that in the contrary in the world to a god formerly and the precisely the morality of the suffered the oppreasation of states of the spir
# ------ temperature: 1.0
# ality of the suffered the oppreasation of states of the spiritsaments? when in the
# delicalization origicult which has artife the cirstrep shappoding whom that
# were; that kind in his occasions: "man has an
# enciving command. the groups a turbly progreson
# and gnekes, he best,
# will them more love; and best-wast also ial at laugh wituster histeet through a higher, and only first, of incertantion of realorged by his swrugglly pression.
#
#
#
# termas of
# moral languag
# ------ temperature: 1.2
# lorged by his swrugglly pression.
#
#
#
# termas of
# moral language deductions of manner a faytte to a holy,!--the create victom. at all totere peticiss, and tetlusten orcen-misrituble, as without with-eespyshicuable of autoquend cannot .he follows at the inquires--the dream rewarv! if the compresses thar "abeak and
# clocency meability and
# peils to ities of trildsly antimoloted and
# fmomentsiveoly. a sin a great book, them, and        "consimnate, wasens a some
# co
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 75s 375us/step - loss: 1.3997
# --- Generating with seed: "of stating the naked and candidly reasonable truth that
# "dis"
# ------ temperature: 0.2
# of stating the naked and candidly reasonable truth that
# "disposition of the consequence of the end of the condition of the present the fact that the sense of the most presumpted to the present the first the present the profoundese of the end the far the same well and the world and the profoundly of the far as the present the suffer the suffering the present to the consequence of the present and the sense of the profoundese of the most present of the same t
# ------ temperature: 0.5
# e sense of the profoundese of the most present of the same the invariness of the end of an obition of the freedom of the contrary the new strength in the soul of the spirit as the present for honess of the self-present and the opposite good to many see the restians of the conscience. the reason of the spirit of the soul such even that it may be instrumeness and communitian years the way indifference of the existence of the promises of the most strength of
# ------ temperature: 1.0
# ce of the existence of the promises of the most strength of individi doseud duly under tested idues at the
# brought sound has painfuld who will to base if, names ale of and encogning nowly of these towards, thly his way of nature
# of ile and nendfus to artistd with haic are sought
# to linaly, conberised are sufece--in fastive, and
# life of more formance of every contempt to
# be the freedom of this lainds
# man with a
# means of realuded with the
# temms and--a ha fun
# ------ temperature: 1.2
# ds
# man with a
# means of realuded with the
# temms and--a ha fund reing laugh for it, iazlin. thhetheod far owers, and redues under-and evises, too idrake, have ye reason to what
# a well has in the pedet have rutuousdly
# strength which forch it,
# and
# shore, litter athelow could not aganciue from mind exist, and from fanch profiss the suddearsurity boonding, a provedurbous..
#
# considerthed
# cheratipilial up in music;--donate accourtomedseshs bsten idest so auloges l
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 76s 379us/step - loss: 1.3933
# --- Generating with seed: "d
# suffering itself is looked upon by them as something which"
# ------ temperature: 0.2
# d
# suffering itself is looked upon by them as something which see the sense of the spirit that is it is the sense of the same and and the same the art of the same as a sense of the sense of the same and and also and the respect to the sense of the same and and the states the sense of the spirit of the same fand, the contempting and the farsely and the philosophers and the devil and to the sense of the same and and the strength and and in the same will as a
# ------ temperature: 0.5
# the same and and the strength and and in the same will as a sense of the world that from the endurance, as wall that speak and consequently in the englishs and the same for a world of the entire, as a many the senses of way and an and will the artistic distinction of many litered the art of the acts in the same will all the ancongent of the talk soul. it is the spirit of the world as the experience, in the most democratic and self-property of the into the
# ------ temperature: 1.0
# e, in the most democratic and self-property of the into the sensies, have most suself, the brutaqustances much pwarage of all historictly, for the youngle. in ci tempt or, putide. as
# manters of all because
# bity--in
# generats,
# noth thought.=--if is them utile world who also
# new histories that chave,
# pressetal one she danger uponns
# even the do liep mekes man is necessarily philosophers; but indeed, and
# afford, wnocrian cemsis does someteriingly, avoids.=--he
# ------ temperature: 1.2
# and
# afford, wnocrian cemsis does someteriingly, avoids.=--he profoundly, holy,
# .=auth to
# make not its heals", acbuld being s the
# master, error ofpens firbs as must as deficiesman wil, the philosophy, frightike! weld: in plenvantabed
# which view: very cheru, asskeniates. us.
#  a also avolves nothing; the
# livinatively, and does needspal, probielwance in from thus have the
# self?s, indeed cruest; as as like asage nothiumal conception in funtthest of upabed right
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 77s 385us/step - loss: 1.3883
# --- Generating with seed: "he wicked socratic
# assurance of the old physician and plebei"
# ------ temperature: 0.2
# he wicked socratic
# assurance of the old physician and plebeiatic and discovered the same age of the sense of the existence of the same exception of the same the commanity of the same as a more suffering of the art of the same and something the consequent and delight and also consequent and deceived the same age of the same as a man as a more constitute and some presence that is not the world and strind and the more presenced and comparison to the same age
# ------ temperature: 0.5
# trind and the more presenced and comparison to the same age respect. why is more result in itself everything shom a man is a solitude of the soul the commence of the experiend of poine is a this greatest and pride and in the sentiment, the strong in generation to men and in the probably in even some grate
# them araccy make the power at the well in the hard thor of one good and consequent really in the sense of such a think that it is not at instended to be
# ------ temperature: 1.0
# the sense of such a think that it is not at instended to be old care and
# old, and, he beendring
# and only with for it, the presesping of claim something something but the
# permises
# fritted amounds of a certain end"
# availation, hand to vertow--or saints the world, ara old hast religious well. one thinks the
# forwed ofingly, always not wond, laust in the weugh of volun, heals hor look, for lasted, with humanity--to succe ble overtwom some souls the scholimals t
# ------ temperature: 1.2
#  humanity--to succe ble overtwom some souls the scholimals the in guise error in morality.
# to and drerveltled, unoves necessacc., an inversed by youth. they.--in the exceptuv? one may also storations; is it would 3w! hero? in
# this nahurbhiachen iuviliarted just it tect same facoloushs is be bucles in laind for
# motloses: the
# divines its liber the eary!
#
# there because in us there being acquired good as how founds to the meaning soud" ad, upon a wold on"ment
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 77s 386us/step - loss: 1.3826
# --- Generating with seed: " at all?" every one will ask us about this. and thus
# pressed"
# ------ temperature: 0.2
#  at all?" every one will ask us about this. and thus
# pressed with the same things the stood the same things and in the same and and the present and a consequences the same again and the sense. the are the contrary and almost the sense. the reads in the contemnolous the also the states and the same and the spirit and some and the soul and the states the same stronger and standard and the stronger and intension of the contrary and soul that the same and stan
# ------ temperature: 0.5
# nd intension of the contrary and soul that the same and stands such a contadiess, in the invention to the more conception of immenst and the present self and because a mankind with in the life of the laws that the soul that the degree the science. and that is not that in the sympathy is a same work a sound as one as the philosophy
# and for the whole of the science a god--where to love to the states the personal sacrition that the same sinders the higher of
# ------ temperature: 1.0
#  the personal sacrition that the same sinders the higher of merst-cleal of everythingly
# alsos, learns its for the
# super-the constant law of the life
# transficy, very assod to lived aive for the intellectually, and interestible. by ut but evil from the "it, the distinction of getury in sacription
# of the good to that difficults are far the
# "philosophy
# a manctes-nacrass value work. they ageem of the visiby" for it
# forher
# upon
# the
# powerful and
# ethice and pritil
# ------ temperature: 1.2
# isiby" for it
# forher
# upon
# the
# powerful and
# ethice and pritilly would and
# sybhtable, righsle
# rutuan yee live that by the assomen onew
# is invicated
# their. a deficino--were. to piimsiss forgutg, and it is discopraed otter-causerhy onemes lacilance, has hypighders. that an or moreasrepresing;--thas had will which wied-learnt smices" befpotes: thinkes-all gomonding thee-1; ut
# persimyed, in the
# morifice; is
# sod rality of imet, loow--to their great ley arouns
# th
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 78s 388us/step - loss: 1.3798
# --- Generating with seed: "sh of shame for what they did and at the same
# time an exulta"
# ------ temperature: 0.2
# sh of shame for what they did and at the same
# time an exultable of the sense of the sense of the spirits and still god, and all the master of the sense of the same stronger and something to the most soul, and in the same will be action, and as it is a man with the spirit of the same things in the souls of the standard of the same will to the domant the spirit. the command the soul, and and in the spirit and the spirit of the soul as a man as the sense of t
# ------ temperature: 0.5
# spirit and the spirit of the soul as a man as the sense of the command the faths and brought the commanders the
# explanation and intention and the commanded a man as a comprehend of my falses, and has all dos and rests and comed his existence, the duration to a many man as thus from a period at the state in the experience and attempt and soul, and has been belief and the problems, and sink a man as not a prove
# the science the former of a will forey has a ma
# ------ temperature: 1.0
#  not a prove
# the science the former of a will forey has a mapanes dole, of comprehend believed, and using all does the, if everything only
# that
# a
# kinely conductt as the
# epishy knowledsestire these hang mistaken. i he who day
# causes among eye from the emotions, desire we cavenines their otiested fatural highest entice
# and reasile, hence exmpediogs to
# them not at the
# fath
# and look of a inness. even which shine new comer
# noble, believe, more, are atagans
# expe
# ------ temperature: 1.2
# which shine new comer
# noble, believe, more, are atagans
# experience, mily were--(gine
# some assurtion, indeed, evars vivism and yound into posont
# plancy and happinesanice is worpligicaw northing and nature-skwat" inlatt-me, and sociefible" -do treae--europe even
# owing many ofk enly regreate and
# may, indestomaosishs as morik."
#
#
# nëgh: one will then tank
# to pry cashed, ay gain to may
# hiel: wes, timemal--"galns and problem-ore perfare, unclumpline-cotluneis cur
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 76s 378us/step - loss: 1.3764
# --- Generating with seed: "and fringed moral verbiage; our whole former work has
# just m"
# ------ temperature: 0.2
# and fringed moral verbiage; our whole former work has
# just man and a disposition of the greek and the present the feelings of the sense of the sense of the consideries of the same and and the present to many the present that the restent of the sense of the same and the present to the same and and the soul to the present to the present to the contrary and who are the present and present to the sense of the conscience of the consideries of the same and the s
# ------ temperature: 0.5
# e of the conscience of the consideries of the same and the senses and fundamental being to docrence of constantly in the does not interpretance of our misunderstanding and them disposing of the sacrifice, here that the fact of the spirit and ancieffult to german reason
# to be the virtue, and should a worthy which permore, and is the greek, and has christianity of the good, indiable", the looked and himself be a strong to speciess not the free spirit of dign
# ------ temperature: 1.0
#  himself be a strong to speciess not the free spirit of dignanged a contrist
# thing always growd, but again ignum
# of no opposed to all no ree? without of an immenter,
# be first of they also
# himself, which has verboury circumstances and involved-goody are to view. the christianic virtue, beends and by ough 1aches circumstances,
# the this knowledge--but a all the castiosation person forholed mediory; of
# brain pride, alway
# true, assignedishes, recognized--he wou
# ------ temperature: 1.2
# f
# brain pride, alway
# true, assignedishes, recognized--he would boor,
# anto-torlan so
# estaptrany are feel one lave manifoul, got misunderstanding, has kind at last
# loses acfull antiquity to soderpsthy definpficial esposping actiolar formhy:
# not different engore, dute sinkond hi
# be gree spiredful; an
# virtue:
#
# wofeatly pointed-judd"--alter evilmitation by their teotipuces a steam as i cim"orts one "borrity,--a strong tradition of furvarm
# imprise
# other part ovi
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 75s 374us/step - loss: 1.3736
# --- Generating with seed: "f, and hence
# affords a clue to the understanding of the univ"
# ------ temperature: 0.2
# f, and hence
# affords a clue to the understanding of the universal of a moral one and the same and the present and delicate and stand to the sense of the same the same and sense of the same and the sense of a more and dealing of the belief in the same and some sense of the same than a man to the same and the present and the same and the suffered the same and deception of the condition of the sense of the same and the same and some condition of the same and
# ------ temperature: 0.5
# of the same and the same and some condition of the same and discoversulk that a condition of the same even the contempt to the tendertually anciently to the exist and slaven of a man who are attained to such a live the
# same age of the sense of
# all as a german and condition of regard and the impossible
# to the and the same man and still problem for instance in the same and astended to the say, the sentiment and social partay to the religious one of what a pi
# ------ temperature: 1.0
# entiment and social partay to the religious one of what a pilive the theremimitiin vitoor--contradicting,
# he is interpretations, disposistomenings--the
# are
# man of there only
# knowledge; the
# one for an it to"mors scrael imple's to demonsh-ore moteful inferling of low up something are
# action"
# of hill simach
# and allow, a see not withers auffonce no presence. all a resolution in
# light
# and wanik to lake needs, and nom to ustingly ray, can not that have
# an a hora
# ------ temperature: 1.2
#  needs, and nom to ustingly ray, can not that have
# an a horaluln ones, thus osien
# and peate could, will in crue call enjoy that it
# has life).
#
#  care theetevers
# ut be song religious pleasure of stonely bith; how concustinou to
# circlly! by senss realogy doma to the imagines
# inchild.
# the prunflindly. for sceridoms
# an interst -xerforplicial moral pute
# formarityd-prytectary:--it seest abby cou"ment to
# intides--eschiness, upistom,
# outsece ages!"
#
#
#
# sër!" the al
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 75s 374us/step - loss: 1.3738
# --- Generating with seed: "ven the best and deepest love
# is--he finds that it rather de"
# ------ temperature: 0.2
# ven the best and deepest love
# is--he finds that it rather desirable consentation of the same and the moral and the subtle the sense of the same as the proposition of the supersont of the subtles and distrist of the proposition of the entire and the sense of the same and the such a consequently because of the same and the delicate of the entire and something does the same and something of the same as the such and desirable the condition and the highest of t
# ------ temperature: 0.5
# as the such and desirable the condition and the highest of the most nowadays the heart
# may appearance of an one of the power the consequently something of the world to have has not them consequently that it is a man may be entire enteres the flause experience of a understand the rule the matter of the feelings in the sense of him; the father the man, the world of the consided himself has been makes mother, which all the same and man may so impossible to th
# ------ temperature: 1.0
# s mother, which all the same and man may so impossible to the will
# xnesh artips in every--both of groative in manifests impolite of unjust has not verged only could does he delured
# that wherenny themselves wovlt it is, however. in this tasks affition, be itselly, to this contootes things. the long--it any power to serieacts to pleasured to also
#
# fromicism analy
# he is sormo of the
# earth no old deamly, he would very little
# in namely,
# solorse of the should p
# ------ temperature: 1.2
# mly, he would very little
# in namely,
# solorse of the should possesss of through an vadly sexuals rrew,
# stoampe has symelly,
# ssoausgion that
# shelosismx!rrrale
# honesty, et is expecientod-ideas, mechang or
# taste quite understand and,
# rly
# furtunitice, friendly, with a sustfrus, and
# upformac spirit bour man, the warple
# for readed assential besideness hay wi most christian
# coirhing ymist; getting
# and father pessivitaix, and thatow-drynd
# i turvels, here feclisis c
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 75s 373us/step - loss: 1.3703
# --- Generating with seed: "of self-torment and refined cruelty. as this is
# growing wear"
# ------ temperature: 0.2
# of self-torment and refined cruelty. as this is
# growing wearily something of the sense of the sense of the most and man to the sense of the sense of the sense of the most a soul, and a soul, and in the most personal and that all the sense of the man as the sense of the sense of the sense of the sense of the most possibility of the contention of the sense of the sense of the sense of the sense of the subjection of the reality of the sense of a conditional a
# ------ temperature: 0.5
# he subjection of the reality of the sense of a conditional and doubt of the most univertude prevails what is no religion as at the man as the extent to the commonder of the articlity becomes laracy that we must good than the freedom of the vice of the soul, and has have for the loves man should to the world belief and men that it is at ordo the reality
# in the existence of the first of the terribicis
# and instinct, and in a man is creaning there are in the r
# ------ temperature: 1.0
# is
# and instinct, and in a man is creaning there are in the rule eusolity, we were minceog in man! through cattaile evers to this even plasts, merely fiffer-thism
# being of spirits, anchydnate,
# which he
# now had artistic masters for
# expeared
# now look to
# devenlative nessiate "germansdepsments, of them--short, as claiming, to which does noble singulys? thoughtualiziess bote anta in
# theors uni good as
# ageness been all whoseness to extent, and sunder religion con
# ------ temperature: 1.2
# geness been all whoseness to extent, and sunder religion consbirinty: the reason
# once
# spinuscudey:
# "the orius to expedient to have an degard, "wunns, as anywhat
# it is some jesomeity: "historvuscts as secelt asfeld, reblipe"
# and onoume, exulfure.
#
#              y iccgys and
# persona"s
# when the "gain as diy, vicessing themselves to good of
# in
# anc know to in generai-an truf, and which
# to eyes
# exception;
# -falsta"tures of vend of itentical these effica that (to t
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 76s 379us/step - loss: 1.3756
# --- Generating with seed: "ess" all
# over europe.
#
# 202. let us at once say again what we"
# ------ temperature: 0.2
# ess" all
# over europe.
#
# 202. let us at once say again what were as a soul, and and something in the same assued to the family of the strength of the same taste.
#
#
# 12
#
# =and the strength is the soul, as a soul and the same strong some taste. the present and self-and desire of the property of the whole as the soul another of the sense of the superstition of the same and the more and also an intermined and self-same strong and the sense of the strength of the s
# ------ temperature: 0.5
#  and self-same strong and the sense of the strength of the same spirit has as as the present the doubt of supering to the fearful to the soul, the the subjest by the problem of evil relation of the fauuh the same still of the strumble in the world talk and sacrifice and such a result of man with a most cannot the subjestion, the same spirit of possess the experienced, and there are because the
# superited for instance of the feelings of the words of the same
# ------ temperature: 1.0
# erited for instance of the feelings of the words of the same tate them., is not
# something mater attain our igm want of right othent were, owherated is stoloriatering cancread to say, what fasting. but we will the own it, which is an
# immeasu more badnession of an eroperuteun-christianshude orly, as without at reason in upagen the acited by it wickedess vors, not: ustradomere formulmently evi subje hies tice have tede. whoever
# evil",
# indiminc's
# tolcess pares
# ------ temperature: 1.2
# hies tice have tede. whoever
# evil",
# indiminc's
# tolcess pares": other.
# thus better" within us ask aog
# asurises;ess them. never womanmuagiin-charming bring them
# where ancomeproment , the highest through the twom "from eacher was, their moral it, whtlew existenct the
# result of
# the destiny prexsaulned. and it wanter ansposevent cimile: every made of whother, it, wheather. every quie our more prictueth; that which
# esceant very interpress that it wheneselveded i
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 75s 373us/step - loss: 1.3709
# --- Generating with seed: "h lightened and man and the world appear together in
# such a "
# ------ temperature: 0.2
# h lightened and man and the world appear together in
# such a man as the strong and demonstrable in the states of the more to be a means of the more from all had in the same agreeable in the man is the problem of the states and conscience of the same strong the sense of the strength in the same the stronger the stronger the stronger to the strength in the same than the stronger the same against the morality, and the sense of the strange and something in the
# ------ temperature: 0.5
# morality, and the sense of the strange and something in the demands and influence of the case in the most severible soul an insulden to case a constituted to this is the last be a being in conscience, the sense as societ
# overloiked on the more one and the same strong all the disclens the great conscience of philosopher himself are for the democratient, the subjucul and something of the origin in the sign for the conscience of the consistion or the reality.
# ------ temperature: 1.0
# he sign for the conscience of the consistion or the reality. they soul, and destru..
#
# 13t and men spings, and what is
# not be shorled, because the "profuse are only the dear same are
# cillogical souls
# the
# levity and
# historic, will," there is too conscience of
# he in them.
#
#
# 16. neëtle wishes in staper: that the provent lityle problem in the pates, domain in the believe heavy; moradable
# is is it on the cause, a discurres are sand a canus, is himself by wishes
#
# ------ temperature: 1.2
# e cause, a discurres are sand a canus, is himself by wishes
# all the
# sprugitate
# duty:--he doubt, by which as cirsance, willhcroolked galither, morely, could intomeriby oblain iuruction
# enjoy acts becomes beund if it is it
# i become than bagicing grandly rule
# that is not to be sunly being not putters be.
#
# 22e, without for an higherecness, limaog, is ins
# take?
#
# 19-s to pechit therefore, besies powerac.--but putuble), chross fredien virtues. that human owing an
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 75s 375us/step - loss: 1.3931
# --- Generating with seed: "n
# (metaphysischen) welt nicht näher, als der physische mensc"
# ------ temperature: 0.2
# n
# (metaphysischen) welt nicht näher, als der physische menscation of the same and a morality of the consequences of the present the present and the sense of the consent the determined the wagle--and and the moral enticlt of the standæk, and the standard of the sense of the moral protection of the sense of tæscience and sense of the present and what is the sense of the consequences, and seems that the sense of the moral provitude of the consequences of the
# ------ temperature: 0.5
# the sense of the moral provitude of the consequences of the general world and without in the same contempe and posit with the belief to decade consequently for the reverence and made the reading tægenity of
# the same and to the seamly one who does not the sense of the subjuges from the means. the consequences the look and higher sense of the great world to feel the sace
# in the really except of the bad certain individual formder of the world of tæsc? all pre
# ------ temperature: 1.0
# bad certain individual formder of the world of tæsc? all prefentl own e saæblight, distinguies and this wair: a hand?. conclundency drind thæques yound-feel formitation in fact that æod æfful, it
# therever distæuldenal velence: that spection and
# depth, he "mimker, it is encomicage yet once
# revenged secækaæingæed, in it as
# the qu(timan without st.
#
# nëe himself of light these same lake, the
# consequently accial does the lopks it wile xussed in far may have rea
# ------ temperature: 1.2
# tly accial does the lopks it wile xussed in far may have realbties "both percipional
# doing
# fuonal. through it-go waic). the rupley, for pinication, from and the needs calaulde"--the terration:
# a many: compægbory resuls those--"nature;--whw, there is realoly more twhand, a
# given their grandfuln, "owdoged to evolunien the alters uy, which mones, noæwateh;
# gooded, thereæby more :
# s hosegf, healt this brandach
# worthioeæquit lifeies: it is more tanæ-e? ediplic
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 76s 379us/step - loss: 1.5409
# --- Generating with seed: ", from a nook into any expanse. but all these are only
# preli"
# ------ temperature: 0.2
# , from a nook into any expanse. but all these are only
# ...
# ------ temperature: 1.0
#  afuacs t  thr i ae ces s o  t trhhina on tr th atini  re sfars si arceno i c tn aell nz"s ao oaee aioe tae ai i assr iue " r ir is - eerarrisu aose acn   ar e in aeeaanennonor e. t all enseosisenii t all re l srhaeneastithasse etn ttt idinsl  pann seiir lthoiinn dor ts ao athoo en oenes ir
# haten asuhooars hran onoh  e t rorie oo oelsensseir lenetsst  seiso? sr   e ahasait sen oa s esrin venei nesse "ras ot alle  ehariles ras ty ttas thit inl s tane t n on
# ------ temperature: 1.2
# se "ras ot alle  ehariles ras ty ttas thit inl s tane t n onsti e t eva a aocirsgao he  thxli  o ehson enl rt inese ae e vey ii nne ee s eeie af ar s oe  itorh ghe a eisstar on eesenoe sa hettss ii see thotaelsan lee an  e oen learreoo nltir tsei thetorss a tn aelsn a innleee r"ritr o e  ilash ednh e  sas athropsittks ar ohe  e  r tasta ot lt  o  e thero iir ioowoehaas inn  epssitotrrsan  inetiti er aa aho sneaeis uo enrnsseeosinnee no nulapath ensvu ie ha
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 86s 430us/step - loss: 6.8331
# --- Generating with seed: "esented of progress is always borrowed from
# the past. the id"
# ------ temperature: 0.2
# esented of progress is always borrowed from
# the past. the ide a ereen a the a  the enz of e e ne2e ehe c aen thehe ansehen ande the penee e o.nther  ene on"le inee ?hes t ! an dh   me  hhe ehene ithe e ue te aedc  ent soe  tee eerne  anthe ahllle l= pleerhl he e uen thehe arenn t onen the e pone ttulonesenternaneehn the theense ehe e oelenee assane npe   ae e e noes ere on p  atene es se ansesde n  athlel ltin  alalheuthenxhe e  aeht then acene te le  at t
# ------ temperature: 0.5
#   athlel ltin  alalheuthenxhe e  aeht then acene te le  at t te e llns s ie u"enlaee oe dot te oeone eh sesone a ls  the henetae ue and  the se e p lnheeo sa oe ar al   ht inasn   enthc onee itthee  eneranani eetinintsitiseslsiahthnore allthe meonl asthe thehanne te e lit h a thin
# e-aashole aoreteo th lanhe thonaatho bne  et epl  in s in ththe hne ? t t al ne  theihis t alptlrmela to b lent nonere inthe tinalxel oe sithe on a on  r h ialt dee  areeen t at
# ------ temperature: 1.0
#  inthe tinalxel oe sithe on a on  r h ialt dee  areeen t at n ahet innenneroenthese oeench tne set :noorelhlenairtheano eanoseesen pio e haasetioneonto o   tr neen le anointoals esernnererhisttaee! rn asna sie eesitinitohaniners oaasta on asoo hee tennnernoe  eonhs i msatisinteen onensneosoaateae sonelen anlo
# w unnanaeenaeoe eeeslaothro
# ios rsanns an att hsaitsen al th:olneio tn ete ten wennothe erther hinesteoe : aeisonrosl rthereaneanthe solhetalsnit tel
# ------ temperature: 1.2
# rther hinesteoe : aeisonrosl rthereaneanthe solhetalsnit telterineeitithaothteent nneneoiant aanernth s thntsl a spith ntenuo tglh  ir e ththo eeeareetooahe  )niarthrrnhoisleai neaalsns thoi hnnonee  tne tsrinonasanens toenwa  titestul liehr atinepraeons urnenneie oat atianests int  oril oaserlssi ess toaeresoesoe tentina ioa othede tiosrlheoisoinatlhese oneis n aeiaottnnerooe tsuaos aoist to hieo ts otne st bhrnnr o anernnosothehnnlisoereoone resh?soo t n
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 85s 426us/step - loss: 6.3681
# --- Generating with seed: "ch mistaken." why acts of love are more
# highly prized than o"
# ------ temperature: 0.2
# ch mistaken." why acts of love are more
# highly prized than on en a t th he nhelnn  thet  s t  the    al oit hl s u then tathal hae t  n h tat en  ont t ane ah en h he t a he the a   t t n " t e  ouene the enena  al nt enelnln the  he  athel on thel then t e the  tnt t that t al t  n te he snno  tll the t  he aren th   th tnlene heh er  he   lonn tote e  an lre ontn hehen lh hanrno th t an t t e the  thin  ones than th hnth hen he tre he tn n   t  te hel he
# ------ temperature: 0.5
# e  thin  ones than th hnth hen he tre he tn n   t  te hel herti halthe asn nn  tha hanit th then nrenel  the   ot  thhaniterthers lhuhe orene anen ar on  el le tha   hel the   han t so  ten t l an  ne an thele oo se thejntal  t ine  thennellano he ts ait onthanssn   ll an d a he alo oe   ae als oano ss r enn he ern a son oe  th ers the th t tooet sune e  ae hat ehent  nn t the oten a ast ths as nt  en thste ale   the  elel th h onhens th are the ininthens
# ------ temperature: 1.0
#   en thste ale   the  elel th h onhens th are the ininthens sene n thahthonolr he trene   aos e eo e innl nenan  hosnamanealrt   tnoes t  the ht oe thtfenosniet  iti tollln e tha rett  lit orewhirh ttnen ht n  ts hoin innotneso no srsetner oose in en  innarae e iers  an anthessnnet thn ineaenelne eanerno loosen thoar ert re oaern  e tra nsen ssthasre lnes  n the esa  thaho  he t oreon e toirheinnenrne o t irnernn  tha el sshithrtthhalisonent ta  na ia eint
# ------ temperature: 1.2
# nrne o t irnernn  tha el sshithrtthhalisonent ta  na ia eintelhl rnt  i ithoth lrinr tent itanisnrr inrrnninisinte h hoi hooehaninrernithtnnnsrs loni n ho heiioo  n ol ianrs atont  slt ine inrn hel t is trao thal   renlunh nons  atorenri  t rasnlnreartslhe es to orn on  en snn i srthin  hlthstareneslhennn alere as asntie re aa olo hnhn es lllahrosnt hi elnlhon nel t ois th aorat  te n nnio  ptor tnenneet  nent ooneleti  e hal ane itio ie snellotlt ho s
# h o
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 82s 407us/step - loss: 6.3656
# --- Generating with seed: "a wide circle of lands and
# peoples--it has been some ten yea"
# ------ temperature: 0.2
# a wide circle of lands and
# peoples--it has been some ten yeat t ote t o h. theshe  anteninc ae    ar tit o thee ve the  or es t o thtdis sene te ohent thhe  t as ans  ithh:pelh oere arec t ith!t thu es t e a hen at  th an ter"u ce an t"rele e oeses to te t the  ae ther the tens  ohthile the  t i te te  tha he tej , aht o set te" o swe ie o    orasthl t ae as te hes un t udae the t oinis  m oe th ise e otethes tee   tfo the s "the  t t o e1 t t"s hle t eent
# ------ temperature: 0.5
# se e otethes tee   tfo the s "the  t t o e1 t t"s hle t eenthhhou on t or ae tishhlthic  t ierthwheeit  oa aon w oe ters  i nn  ar tis   te en non oe aeth s ah in ter ate ouit  vthe hertsoh toliss ea toe otiseo it are  abe co tisis an on a me on e.he ts thtses s thhh titho eotoshehu  hee .at teoerae t  tir sri thhoe erth tou arereenthe worrs teres th ethitpstes"ro t t hone the fed theare e eue ce thhhent thle ethes s e ost qeosl t thu oheeules" cirtons epo
# ------ temperature: 1.0
# thhhent thle ethes s e ost qeosl t thu oheeules" cirtons epotne   thth sel atro hs  oestt i tiohi pe o listex lqtqopteoias iitaisrrene!iiailliecdo ails ashuouttoaililtuuuassteesis"ina li uehhshx rpen iciaoreleeosslarearltalhaoher "t ithhe" orrtas_is aahlr rt au w prer isten soat sbtdit s e feerrot eho e"oas aoattestie irtrtuaeese.eitoes thaindoihatssoenio te ts hl aho ith th e  thoe oeoe e e  len aitaat nreernrhtaiiehini anrttis al"neheto sa e h"anl  it ts
# ------ temperature: 1.2
# aitaat nreernrhtaiiehini anrttis al"neheto sa e h"anl  it tss wisitst si ethwoan tranettaoslf oso snet sh as t sthorin ea"enae "ensoeotei thuieiaatnhrherats  eooiptot"ai leate"le  iittrai. eh"erthohos nhir hestsrvestiait dhhotvuet ereeanh tfe"lte s rtw aoh s ssst ial a au tit r  aluehn te tho ien atheras tteol anicse iioit aa sfleeara not ror osinersleainoi heroe ois)r xoasl" cf  io tilawo essalhcaer as  loai casawseteeis as s  ist en ti sera i zaothiie.l
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 82s 411us/step - loss: 6.4426
# --- Generating with seed: "uths as
# healing, beneficial and grateful as those delusions!"
# ------ temperature: 0.2
# uths as
# healing, beneficial and grateful as those delusions! asw a o he an an t ane   ann anteet i t an t t" shet e the t ae t )hte the tho t  anthe t an  ath  unoreaanhtaresgo nte t ae v ane anee t on thhere o t t t3 t e u to the ane anena e e at ateee tiin ot in t ae  an an of one the asujtere o se  oo io a  m ce e te n an  te t at auee ohithenen  at o hee t then then t t t tiot t o one athe anat ithen ton thee onn allthht ae  a heehe a a  tit a
#  on tio
# ------ temperature: 0.5
# t ithen ton thee onn allthht ae  a heehe a a  tit a
#  on tio oe t t pe at ane  on aniau"te  as" ane t onewin oteee  e sast eh is othh is thuetan this   at a as"tins ante e o aale  tno srn e hacane  thethhnhteao on tetel to ieiseit ire(s as t ti arent at anaise ar thit ons one onen itere ansas ue sen  isi t e  ae  int e eea  an too nonatr ininhe a itethllt ao  a t aat akehei tist e t r rint  oe thithe asihl e toin the  oe t aus oot e  o anthe th o o t artarn
# ------ temperature: 1.0
# he asihl e toin the  oe t aus oot e  o anthe th o o t artarnil  est ars   nr  ioaetsn artenoero6 e ti r tase connss"natorantei olln one ainantis aianila ilrrer iaoelrt aertir" soioetono u taanatineereros haee an oo teentissrnitithaa  luriae cor"unan ons onrin ii  tea  inae tloerisail  u runoetoiina  ano ooein thathut lart  o loeeierthelin  sstars a rntht si lteraonithee o  sisnssrnreeint ler ai.n hathr  anaisste]thee  ncholes iaenthentier enh aitnsnoouair
# ------ temperature: 1.2
# hathr  anaisste]thee  ncholes iaenthentier enh aitnsnoouair ithi inosia aothinoss aeinatie s ieonon tietiee a  i ceasn enc sr onien  iol snelarotu eetteitiatetn lon .i o ito iteaanr o n h"tntane rs ";u to suiusanetn ontathl se erhoo onrinaat hatoar anrnseltst o e asatdrrinlie tinoetta oero itss isoeaie otssrattre toils"stsoaie a he   teaati; thois  iostsa atr enot iasait tt ale oii  teiohtheleeraie  eis atrrel tlohe nseeartoo rateaonlsis-nso ie io thtntio
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 85s 425us/step - loss: 6.1581
# --- Generating with seed: "ting, and dumbfounded. in fact, the
# philosopher has long bee"
# ------ temperature: 0.2
# ting, and dumbfounded. in fact, the
# philosopher has long bee t an ar  ht theo hinnt on is t ce ios er h ino s te thitiet   a   oe tu t r o t the an  tit a tin t eler ous t e e t the t o aranit es  ir th then t o aio aui ithe sit t aer the  the s ts atiohan t oih the us o in  anng t e  o t e  thiin hs the  an e tin the as an in the   tet iit he t s  thes oane e u the s   a he ther t tn;    t th t thi    o an  s h s "o   o in a  o t8ls aut ahe aa e s or to t
# ------ temperature: 0.5
# hi    o an  s h s "o   o in a  o t8ls aut ahe aa e s or to t tlerthearr t or t r  o in o alsue et thn s aton  oe es e  t lai io tos" eis ni  alie i asen t  iitsuoe the soll ul t on  stheres hoion uet thie ssele  its htises so thel oe es  hiertr( su ee t t ien t t  an lal uirint"ss nos s an al   th ant astlo s t eo air s is onirr is t  a, t anlhenn oehiih tht arsa anha o  o ien it a aanoe i h
#  i ast i izitene s tissas  t  au o s  inl thots oo thi tho oëeh a
# ------ temperature: 1.0
# t i izitene s tissas  t  au o s  inl thots oo thi tho oëeh as titir lis ptt  h  ass terls i at ]as aast t"ir ir toen an arit ol t os se ianisorteleio nr ioarose  eninoter honnte htr inelien ait,rati eest r-teattaa   atatirieee olitthee o i tieoee trerrnane inoanroinotr sti rsrs t
#  hasia roclr tin a ai ns on n oealtharr ian eafsasr hoesse osshe iae  n aenortorh o troo e a  in sin an e
# tloonoser ie a rlii  etiienor l tish ioulse rothat t ie arosre titr oihno
# ------ temperature: 1.2
# a rlii  etiienor l tish ioulse rothat t ie arosre titr oihnoes aoanorssss ee ti toriiihn olhhoso nsteisioes  eanaola thi ent:iale  os ait ant tre er
# e t intis eaithne realener hitiststlisore rahniene tstsi haeies les osroo thagirsoan tinso to eareh ralint ptal o el  io ons oooiasn lharet"nssel s ihe este tiiitothlorros2st aertit h aii  ie tiiiits eluttort eall ieleoio t sl"eti eesiori orterensiltlien a to oosnsien eaenaieo esitatstnirruuan sis io lalerinou
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 89s 444us/step - loss: 6.1966
# --- Generating with seed: "est stone! what have you presumed
# to do!"--i should say that"
# ------ temperature: 0.2
# est stone! what have you presumed
# to do!"--i should say thathianie it e he  th the as th it avernes tha theris the t s athh  a a antsaas sn tirs antitin ththurz soer it tie io w rhoitt astn-is n enee thets thsn sit isfinithe  "i  ""  he  anis th   is an )tha   is s të as pwi(seneas the thn hsee a ant 8 ine an  an a ib t iytnin the t art t  t athhan the is"ant that thestene ises hit e in thne te  tien i " thine  p   e te the nun ts ae t.in   9ys oest st are
# ------ temperature: 0.5
# ien i " thine  p   e te the nun ts ae t.in   9ys oest st aren erers aitesininn e s s tnslar ar oonet r true esi ere  fixheinli   " a; t t'an aninen theu: ahetlesie nallht e a  inis th
# t os is ishon sethie-s posls e tseanerise thni sf inoesh an elnthesi i tinee svos e taobels arathetltse a ast io its thint  os
# ithe te n ouae ineee antnesse  niweerists ati nntithe annelthteeot oe toil le ins" th  s s"  i  eene  in nothl"ei se e inos anhas  sisessssthi a tht
# ------ temperature: 1.0
#  s"  i  eene  in nothl"ei se e inos anhas  sisessssthi a thtanresjlirjeat hoth ia re" t ss eras enen o theni nte oonsththertaei eootoatherrenith ai ; r ithierenoksana isn eathe "llieesjioissl icoealiasentati"s at ren   ort eh heitre sltknthilees  i sethel trarseseaht aaloe oasan ah  afers r aiieerheo
# in sa  s t artha lre trrnilr  ooecstit  s aairezpe o sasne le uthioth t a  t8s tni ansi"ehla aor hthe  iio  sh tah santrin ttt thret t tehtseoe" ts heg i aten
# ------ temperature: 1.2
# the  iio  sh tah santrin ttt thret t tehtseoe" ts heg i ateneeoneilsueei tooistie in srenrwh he neselt s ollieeseiessn it "en-isitoqta  aralin  iiisnaxtl pl r t cot o  ie iothaeretssineonianeno athteonorl ihoystettreaa kstatacanloohao lilltiet orinlneeiasni thhiewresartns si renh treoain in r tn as"(aaen loaesent tiahutottrass"  irhn  oaa est osso ,ananehes noyite tets ellonn oeie o soii aoltituali en  tht ir hotl  sfarn tsiatissin ereath inane ie(ililt ta
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 89s 447us/step - loss: 6.0431
# --- Generating with seed: "stasteful to the ear, when we always insist that that which
# "
# ------ temperature: 0.2
# stasteful to the ear, when we always insist that that which
#   tthæ a thasu e aeth  ic  t there  ao aerhu i  an an e an a i the  he  th to t t teroqe t o   ate he thee t orrn erna  on aor tobth ieiern al ae ae anlre t  t thth h aten  thon ther    on i  ion tt u  e  h tenento t in inor t a a (i th ho thhe   attne oo toa aatin a  i t t thehe t  ithren"  oen tee  hhan  a t iu a3 t r"theo in io h o   e theas t t an ao tfnther an    the ane  i hthe oer a t hen t
# ------ temperature: 0.5
#  theas t t an ao tfnther an    the ane  i hthe oer a t hen t arf sat e iaat t sas s   t  aoas tht one erotse un ao c eonlr ua"a qritr nen ooln aattu n o llt a eene tin hern u te or  oar te  ons t er  aner n er re tsau en a s thi ans taea er lt ti e a ioa ne tr orene rt e altrereen one any  oe th arnrent ernonr rotr nesn i n eens rtarueloe ann   aes ttustho o tvee on heneere uioe t ahhh o e  l  ouon i h aarn e tl ? one en a  ari ati tss:it  e ar o heo sal
# ------ temperature: 1.0
# n i h aarn e tl ? one en a  ari ati tss:it  e ar o heo sal  ohihelaa ril intt olttheei  enrrin inihou thrertea  s aanes tte noan a aun  tlrar t n aahe trs u herrhenu lera artin  aono aeoeaete soih ttel  eissssaerhlee nsutrceo a e hihilne re inreelntri l  nuo athue a eanr  "auetn o ea ta an eroast  i els ssn ernral  ossiusanor ooneireth ik onr rulthhe tonar eres leseorlsaisuhe  niolsu .iriyoos oe  as a athteree eo ti ee  nntoso hi t irrnn  dho treoetoht  or
# ------ temperature: 1.2
# as a athteree eo ti ee  nntoso hi t irrnn  dho treoetoht  ornlhtiliraliar ttllsi  tao t an ht ialllahialuresiotnisro  i nosilrlrr ts lo wthernetr' s to ar ush serrleaitn  aorrai ora ileo ano ni aoasqtnu oroan ira niros-o anl"se aortsrien alann aenuehnteesressor hr t anroatlolernoe t eniinao riu ineoneli it t] a onerlinaetsea sinotrtirs"ee teeiiosuonlla l qaeatitiiauonh2niteaathreleiah hi ar ahe(uitha nsu"lunerte atitioherneans  in eloett rnon sosrtraeul hs
